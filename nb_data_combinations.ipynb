# %% [markdown]
# ## Combinations in Python

# %%
from numpy import random as r
import datetime
import pandas
from itertools import combinations
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ### Create test data

# %%
cats = ["blue","green","orange","purple","black",
        "grey","white","teal","aqua","red","yellow",
        "bone","rainbow",'chrome','silver']


data = pandas.DataFrame(columns = ['unique', 'cats'])

for n in range(2200):
    
    data.loc[n, 'unique'] = 'uniq_' + str(n)
    
    string = ''
    
    for x in range(r.randint(1, len(cats))):
        r2 = r.randint(0, len(cats))
        string = string + cats[r2] + ','
        
    data.loc[n, 'cats'] = string

# %%
data.head()
# Out:
#    unique                                               cats
# 0  uniq_0  white,teal,grey,blue,chrome,purple,chrome,whit...
# 1  uniq_1  bone,black,blue,chrome,purple,grey,aqua,yellow...
# 2  uniq_2                              yellow,silver,orange,
# 3  uniq_3  grey,silver,yellow,yellow,purple,aqua,rainbow,...
# 4  uniq_4                           purple,blue,grey,chrome,

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2200 entries, 0 to 2199
# Data columns (total 2 columns):
# unique    2200 non-null object
# cats      2200 non-null object
# dtypes: object(2)
# memory usage: 131.6+ KB

# %% [markdown]
# ### Get unique terms

# %%
uniq_cats = sorted(list(data['cats'].unique()))

# %%
uniq_cats
# Out:
# ['aqua,',
#  'aqua,aqua,',
#  'aqua,aqua,black,',
#  'aqua,aqua,black,black,bone,rainbow,rainbow,',
#  'aqua,aqua,bone,yellow,aqua,yellow,orange,',
#  'aqua,aqua,green,',
#  'aqua,aqua,green,green,green,aqua,teal,green,red,silver,aqua,bone,purple,',
#  'aqua,aqua,green,teal,green,',
#  'aqua,aqua,grey,grey,bone,chrome,silver,black,purple,',
#  'aqua,aqua,orange,black,bone,',
#  'aqua,aqua,red,red,chrome,bone,orange,orange,chrome,red,',
#  'aqua,aqua,silver,yellow,white,chrome,blue,green,green,bone,blue,',
#  'aqua,aqua,teal,blue,chrome,aqua,white,rainbow,grey,rainbow,silver,orange,aqua,',
#  'aqua,aqua,white,orange,purple,purple,aqua,grey,',
#  'aqua,aqua,white,teal,grey,grey,red,',
#  'aqua,black,bone,grey,silver,red,yellow,',
#  'aqua,black,bone,orange,blue,',
#  'aqua,black,bone,white,orange,green,grey,yellow,teal,orange,purple,teal,rainbow,red,',
#  'aqua,black,green,',
#  'aqua,black,orange,teal,aqua,purple,bone,',
#  'aqua,black,orange,white,rainbow,purple,bone,silver,bone,silver,grey,purple,grey,purple,',
#  'aqua,black,red,black,',
#  'aqua,black,red,orange,yellow,black,chrome,',
#  'aqua,black,red,rainbow,silver,blue,yellow,green,black,aqua,',
#  'aqua,black,red,teal,chrome,blue,orange,rainbow,teal,grey,',
#  'aqua,black,yellow,',
#  'aqua,black,yellow,rainbow,aqua,teal,purple,black,grey,grey,green,purple,green,',
#  'aqua,blue,',
#  'aqua,blue,aqua,red,',
#  'aqua,blue,blue,rainbow,teal,aqua,blue,chrome,',
#  'aqua,blue,silver,purple,chrome,chrome,red,',
#  'aqua,blue,teal,bone,purple,black,teal,purple,orange,aqua,aqua,orange,orange,aqua,',
#  'aqua,bone,',
#  'aqua,bone,aqua,silver,green,silver,yellow,',
#  'aqua,bone,black,grey,silver,chrome,',
#  'aqua,bone,blue,bone,grey,teal,white,silver,white,',
#  'aqua,bone,bone,orange,black,silver,red,',
#  'aqua,bone,chrome,aqua,yellow,red,black,orange,green,black,yellow,',
#  'aqua,bone,chrome,green,red,black,red,chrome,purple,black,',
#  'aqua,bone,green,',
#  'aqua,bone,grey,silver,chrome,purple,white,chrome,black,chrome,bone,',
#  'aqua,bone,orange,blue,aqua,aqua,yellow,purple,orange,teal,rainbow,aqua,blue,purple,',
#  'aqua,bone,orange,blue,white,red,red,rainbow,green,blue,silver,chrome,bone,black,',
#  'aqua,bone,orange,red,purple,blue,orange,rainbow,silver,blue,chrome,orange,bone,grey,',
#  'aqua,bone,red,blue,',
#  'aqua,chrome,',
#  'aqua,chrome,black,white,rainbow,',
#  'aqua,chrome,green,green,silver,yellow,bone,',
#  'aqua,chrome,green,yellow,',
#  'aqua,chrome,orange,rainbow,purple,purple,purple,silver,yellow,red,silver,',
#  'aqua,chrome,purple,silver,white,chrome,purple,',
#  'aqua,chrome,red,yellow,teal,chrome,purple,grey,purple,',
#  'aqua,chrome,silver,purple,red,rainbow,white,bone,rainbow,',
#  'aqua,chrome,teal,aqua,purple,green,red,white,yellow,',
#  'aqua,chrome,teal,black,yellow,red,rainbow,red,blue,grey,teal,yellow,',
#  'aqua,chrome,teal,orange,rainbow,white,',
#  'aqua,green,',
#  'aqua,green,aqua,orange,orange,teal,green,rainbow,black,blue,bone,blue,teal,purple,',
#  'aqua,green,chrome,teal,blue,yellow,rainbow,blue,rainbow,aqua,aqua,purple,chrome,',
#  'aqua,green,orange,purple,yellow,black,blue,',
#  'aqua,green,purple,purple,aqua,red,orange,',
#  'aqua,green,rainbow,bone,white,aqua,white,',
#  'aqua,green,red,grey,silver,silver,white,bone,',
#  'aqua,green,red,white,purple,',
#  'aqua,green,silver,black,red,blue,red,blue,black,',
#  'aqua,green,teal,bone,yellow,grey,bone,black,chrome,',
#  'aqua,grey,',
#  'aqua,grey,aqua,grey,chrome,',
#  'aqua,grey,blue,',
#  'aqua,grey,blue,teal,orange,orange,black,teal,grey,',
#  'aqua,grey,chrome,teal,bone,aqua,blue,green,rainbow,rainbow,silver,silver,silver,yellow,',
#  'aqua,grey,orange,white,black,purple,red,grey,grey,yellow,silver,',
#  'aqua,grey,rainbow,',
#  'aqua,grey,rainbow,orange,green,black,teal,grey,aqua,',
#  'aqua,grey,silver,chrome,teal,orange,rainbow,black,',
#  'aqua,grey,silver,white,blue,silver,silver,green,purple,bone,bone,rainbow,bone,teal,',
#  'aqua,orange,',
#  'aqua,orange,blue,bone,',
#  'aqua,orange,bone,yellow,purple,',
#  'aqua,orange,green,bone,white,silver,white,purple,grey,',
#  'aqua,orange,purple,chrome,black,black,purple,blue,blue,grey,rainbow,teal,yellow,',
#  'aqua,purple,',
#  'aqua,purple,aqua,chrome,green,white,bone,grey,',
#  'aqua,purple,blue,teal,chrome,teal,bone,blue,aqua,',
#  'aqua,purple,blue,teal,white,silver,grey,chrome,black,aqua,grey,teal,orange,',
#  'aqua,purple,grey,grey,yellow,bone,bone,white,yellow,white,',
#  'aqua,purple,orange,',
#  'aqua,purple,purple,aqua,chrome,',
#  'aqua,rainbow,black,yellow,teal,orange,black,purple,teal,bone,red,',
#  'aqua,rainbow,blue,red,red,orange,orange,bone,black,white,teal,silver,',
#  'aqua,rainbow,bone,silver,silver,green,blue,purple,orange,teal,green,rainbow,bone,',
#  'aqua,rainbow,chrome,silver,aqua,',
#  'aqua,rainbow,grey,teal,white,green,rainbow,grey,silver,green,teal,aqua,chrome,',
#  'aqua,rainbow,grey,yellow,red,silver,rainbow,',
#  'aqua,rainbow,silver,white,red,teal,black,silver,yellow,teal,teal,purple,',
#  'aqua,red,',
#  'aqua,red,black,blue,white,purple,rainbow,yellow,chrome,',
#  'aqua,red,bone,',
#  'aqua,red,green,rainbow,red,red,black,',
#  'aqua,red,green,silver,white,orange,teal,black,',
#  'aqua,red,rainbow,white,teal,green,chrome,purple,black,white,teal,red,black,black,',
#  'aqua,red,red,purple,aqua,rainbow,green,grey,purple,',
#  'aqua,red,silver,aqua,orange,silver,orange,chrome,blue,yellow,',
#  'aqua,red,silver,white,bone,red,teal,grey,',
#  'aqua,red,teal,bone,bone,aqua,grey,orange,yellow,grey,teal,blue,silver,red,',
#  'aqua,silver,',
#  'aqua,silver,blue,black,grey,grey,white,grey,white,yellow,silver,silver,orange,',
#  'aqua,silver,blue,purple,chrome,white,silver,',
#  'aqua,silver,chrome,red,',
#  'aqua,silver,green,grey,orange,yellow,green,yellow,',
#  'aqua,silver,grey,purple,green,purple,aqua,yellow,chrome,rainbow,',
#  'aqua,silver,purple,grey,yellow,white,chrome,orange,bone,green,bone,',
#  'aqua,silver,rainbow,bone,orange,yellow,blue,teal,green,silver,red,bone,aqua,teal,',
#  'aqua,silver,white,teal,chrome,silver,orange,white,rainbow,blue,',
#  'aqua,teal,aqua,silver,bone,bone,',
#  'aqua,teal,black,purple,white,rainbow,',
#  'aqua,teal,blue,grey,chrome,grey,rainbow,aqua,grey,grey,green,grey,grey,',
#  'aqua,teal,green,rainbow,aqua,blue,rainbow,silver,orange,',
#  'aqua,teal,orange,chrome,purple,rainbow,aqua,purple,yellow,black,orange,aqua,aqua,',
#  'aqua,teal,rainbow,aqua,green,green,rainbow,yellow,green,grey,grey,',
#  'aqua,teal,rainbow,rainbow,',
#  'aqua,teal,red,green,green,yellow,purple,chrome,purple,green,silver,chrome,grey,orange,',
#  'aqua,teal,yellow,chrome,red,black,blue,chrome,purple,yellow,green,orange,teal,',
#  'aqua,teal,yellow,grey,blue,yellow,chrome,',
#  'aqua,white,bone,green,',
#  'aqua,white,green,aqua,teal,green,chrome,purple,',
#  'aqua,white,green,black,grey,rainbow,white,silver,bone,',
#  'aqua,white,green,rainbow,red,aqua,teal,',
#  'aqua,white,orange,white,teal,rainbow,green,black,silver,black,',
#  'aqua,white,purple,aqua,chrome,blue,blue,orange,green,bone,white,',
#  'aqua,white,rainbow,black,black,grey,green,',
#  'aqua,white,silver,teal,grey,aqua,',
#  'aqua,white,white,white,grey,grey,aqua,red,red,teal,',
#  'aqua,white,yellow,grey,purple,black,blue,chrome,white,yellow,silver,blue,silver,green,',
#  'aqua,white,yellow,purple,aqua,grey,orange,grey,purple,grey,white,',
#  'aqua,yellow,',
#  'aqua,yellow,aqua,chrome,teal,aqua,orange,',
#  'aqua,yellow,aqua,white,green,red,teal,red,bone,',
#  'aqua,yellow,aqua,yellow,yellow,bone,red,orange,',
#  'aqua,yellow,black,green,green,blue,purple,',
#  'aqua,yellow,black,orange,aqua,bone,red,yellow,black,bone,rainbow,purple,black,',
#  'aqua,yellow,bone,orange,rainbow,chrome,yellow,blue,aqua,chrome,grey,bone,black,red,',
#  'aqua,yellow,chrome,white,grey,aqua,chrome,rainbow,aqua,red,',
#  'aqua,yellow,grey,blue,green,black,teal,white,',
#  'aqua,yellow,orange,silver,silver,black,green,purple,blue,',
#  'aqua,yellow,rainbow,rainbow,rainbow,chrome,green,rainbow,chrome,rainbow,white,purple,silver,black,',
#  'aqua,yellow,silver,aqua,blue,rainbow,',
#  'aqua,yellow,silver,orange,blue,black,red,teal,orange,chrome,yellow,silver,red,',
#  'aqua,yellow,white,green,green,green,yellow,red,aqua,chrome,',
#  'black,',
#  'black,aqua,green,white,blue,bone,green,',
#  'black,aqua,orange,black,green,green,chrome,',
#  'black,aqua,teal,aqua,orange,rainbow,green,silver,orange,rainbow,orange,',
#  'black,aqua,yellow,black,yellow,bone,green,grey,purple,blue,white,red,green,bone,',
#  'black,black,aqua,purple,orange,black,grey,bone,grey,white,red,teal,silver,bone,',
#  'black,black,black,yellow,grey,purple,purple,bone,',
#  'black,black,bone,bone,white,red,black,blue,rainbow,green,rainbow,',
#  'black,black,green,rainbow,black,red,green,rainbow,rainbow,teal,',
#  'black,black,grey,rainbow,teal,yellow,yellow,purple,rainbow,silver,',
#  'black,black,grey,yellow,blue,red,orange,silver,rainbow,purple,grey,red,white,',
#  'black,black,purple,chrome,green,',
#  'black,black,purple,orange,bone,purple,chrome,red,chrome,yellow,purple,yellow,',
#  'black,black,purple,white,chrome,black,blue,red,yellow,white,green,orange,',
#  'black,black,red,orange,red,purple,silver,chrome,blue,bone,black,teal,chrome,white,',
#  'black,black,red,teal,grey,purple,bone,green,aqua,grey,white,black,',
#  'black,blue,black,purple,white,teal,chrome,teal,teal,grey,',
#  'black,blue,purple,green,rainbow,blue,chrome,bone,rainbow,red,black,grey,orange,orange,',
#  'black,blue,purple,grey,teal,purple,purple,bone,black,purple,aqua,',
#  'black,blue,rainbow,yellow,teal,bone,black,white,',
#  'black,blue,red,chrome,grey,bone,bone,grey,white,green,teal,chrome,green,purple,',
#  'black,blue,red,grey,green,rainbow,white,chrome,',
#  'black,blue,red,rainbow,chrome,orange,orange,teal,black,bone,silver,red,',
#  'black,blue,yellow,bone,green,aqua,red,black,',
#  'black,bone,',
#  'black,bone,black,bone,green,grey,rainbow,black,black,white,bone,aqua,bone,',
#  'black,bone,bone,rainbow,grey,blue,chrome,',
#  'black,bone,orange,aqua,black,chrome,aqua,chrome,orange,purple,rainbow,',
#  'black,bone,orange,orange,grey,aqua,chrome,black,purple,yellow,',
#  'black,bone,orange,teal,silver,',
#  'black,bone,rainbow,aqua,teal,purple,',
#  'black,bone,silver,teal,green,teal,',
#  'black,bone,teal,silver,green,',
#  'black,bone,white,rainbow,',
#  'black,bone,yellow,silver,purple,red,aqua,rainbow,bone,white,chrome,black,blue,purple,',
#  'black,chrome,aqua,yellow,white,bone,teal,grey,black,silver,blue,silver,',
#  'black,chrome,black,black,black,blue,chrome,',
#  'black,chrome,black,blue,orange,',
#  'black,chrome,black,rainbow,bone,',
#  'black,chrome,blue,',
#  'black,chrome,blue,green,rainbow,aqua,teal,rainbow,silver,rainbow,grey,aqua,blue,',
#  'black,chrome,bone,silver,',
#  'black,chrome,rainbow,white,teal,yellow,chrome,green,aqua,',
#  'black,chrome,teal,aqua,chrome,white,',
#  'black,chrome,white,orange,teal,rainbow,',
#  'black,chrome,yellow,purple,black,yellow,grey,yellow,',
#  'black,green,bone,red,yellow,red,purple,blue,',
#  'black,green,green,grey,yellow,green,teal,',
#  'black,green,yellow,',
#  'black,grey,blue,silver,purple,aqua,aqua,green,orange,red,rainbow,purple,silver,',
#  'black,grey,green,',
#  'black,grey,grey,yellow,blue,orange,silver,white,',
#  'black,grey,orange,purple,teal,green,blue,aqua,bone,yellow,',
#  'black,grey,purple,chrome,grey,orange,red,green,teal,orange,',
#  'black,grey,purple,green,silver,grey,red,chrome,purple,yellow,purple,white,orange,teal,',
#  'black,grey,silver,rainbow,black,white,grey,bone,',
#  'black,grey,white,red,white,blue,yellow,chrome,chrome,blue,',
#  'black,orange,aqua,rainbow,rainbow,orange,bone,yellow,yellow,silver,green,rainbow,chrome,',
#  'black,orange,aqua,silver,',
#  'black,orange,black,blue,teal,green,rainbow,rainbow,silver,silver,aqua,bone,',
#  'black,orange,chrome,black,orange,chrome,teal,green,white,red,',
#  'black,orange,chrome,yellow,yellow,blue,green,',
#  'black,orange,grey,silver,chrome,bone,teal,yellow,silver,blue,',
#  'black,orange,orange,purple,black,red,grey,',
#  'black,orange,orange,white,silver,orange,blue,teal,rainbow,grey,aqua,yellow,blue,',
#  'black,orange,purple,purple,white,',
#  'black,orange,yellow,chrome,green,yellow,bone,bone,',
#  'black,purple,',
#  'black,purple,aqua,silver,aqua,white,black,',
#  'black,purple,black,black,yellow,black,purple,grey,chrome,silver,orange,bone,red,teal,',
#  'black,purple,red,red,silver,green,green,black,white,teal,',
#  'black,purple,white,bone,bone,grey,',
#  'black,purple,white,orange,bone,green,orange,bone,yellow,bone,teal,blue,chrome,',
#  'black,purple,white,rainbow,aqua,purple,red,green,grey,aqua,rainbow,bone,rainbow,aqua,',
#  'black,rainbow,black,green,bone,bone,',
#  'black,rainbow,black,white,green,aqua,teal,green,yellow,chrome,blue,purple,grey,',
#  'black,rainbow,black,white,yellow,aqua,white,silver,',
#  'black,rainbow,grey,',
#  'black,rainbow,silver,bone,',
#  'black,red,black,aqua,teal,rainbow,green,bone,blue,silver,rainbow,',
#  'black,red,black,teal,',
#  'black,red,blue,green,teal,green,teal,',
#  'black,red,bone,silver,grey,silver,aqua,blue,green,grey,purple,orange,teal,silver,',
#  'black,red,green,chrome,bone,blue,',
#  'black,red,grey,',
#  'black,red,yellow,',
#  'black,red,yellow,white,red,purple,red,orange,blue,silver,orange,teal,',
#  'black,silver,black,',
#  'black,silver,bone,bone,white,rainbow,green,teal,',
#  'black,silver,chrome,chrome,rainbow,green,bone,orange,green,purple,red,teal,orange,red,',
#  'black,silver,red,silver,rainbow,rainbow,bone,orange,red,green,purple,yellow,',
#  'black,silver,red,white,aqua,yellow,orange,blue,aqua,yellow,orange,bone,aqua,red,',
#  'black,silver,silver,yellow,bone,white,',
#  'black,teal,blue,',
#  'black,teal,blue,teal,red,chrome,teal,black,green,teal,silver,green,silver,',
#  'black,teal,green,aqua,silver,black,silver,yellow,teal,teal,teal,',
#  'black,teal,orange,blue,',
#  'black,teal,purple,white,teal,silver,chrome,orange,aqua,rainbow,',
#  'black,teal,rainbow,blue,silver,rainbow,purple,silver,bone,purple,white,white,green,purple,',
#  'black,teal,white,grey,blue,teal,bone,',
#  'black,white,',
#  'black,white,blue,yellow,green,red,green,red,rainbow,white,',
#  'black,white,bone,aqua,bone,red,orange,aqua,grey,bone,',
#  'black,white,chrome,blue,green,green,',
#  'black,white,green,purple,teal,bone,blue,',
#  'black,white,orange,blue,black,green,teal,blue,',
#  'black,white,red,',
#  'black,white,red,chrome,silver,chrome,silver,',
#  'black,white,silver,grey,silver,chrome,purple,rainbow,teal,white,',
#  'black,white,silver,orange,orange,bone,aqua,aqua,red,purple,',
#  'black,white,white,red,black,chrome,red,purple,purple,silver,chrome,',
#  'black,yellow,',
#  'black,yellow,black,grey,blue,black,yellow,',
#  'black,yellow,bone,aqua,rainbow,',
#  'black,yellow,bone,rainbow,grey,black,grey,chrome,grey,grey,red,silver,aqua,',
#  'black,yellow,chrome,white,green,yellow,orange,green,red,blue,grey,orange,',
#  'black,yellow,orange,purple,red,grey,bone,yellow,',
#  'black,yellow,silver,black,silver,black,silver,',
#  'black,yellow,silver,rainbow,blue,silver,',
#  'blue,',
#  'blue,aqua,',
#  'blue,aqua,aqua,',
#  'blue,aqua,blue,chrome,silver,white,yellow,grey,purple,green,',
#  'blue,aqua,blue,yellow,green,red,red,bone,aqua,yellow,',
#  'blue,aqua,green,',
#  'blue,aqua,green,silver,blue,',
#  'blue,aqua,red,white,teal,white,yellow,teal,',
#  'blue,black,aqua,green,yellow,bone,bone,silver,yellow,chrome,aqua,bone,',
#  'blue,black,aqua,silver,blue,',
#  'blue,black,bone,white,teal,grey,orange,chrome,teal,purple,',
#  'blue,black,green,rainbow,yellow,white,chrome,chrome,white,white,blue,grey,',
#  'blue,black,red,white,teal,bone,',
#  'blue,black,silver,red,teal,purple,green,white,bone,black,',
#  'blue,black,teal,',
#  'blue,black,white,aqua,rainbow,',
#  'blue,black,white,red,',
#  'blue,black,white,yellow,grey,purple,rainbow,orange,white,purple,rainbow,',
#  'blue,blue,',
#  'blue,blue,blue,blue,yellow,red,bone,black,silver,red,chrome,teal,',
#  'blue,blue,chrome,green,red,chrome,bone,purple,orange,black,purple,',
#  'blue,blue,orange,rainbow,white,chrome,bone,white,',
#  'blue,blue,white,chrome,teal,teal,purple,green,green,purple,grey,',
#  'blue,blue,white,teal,orange,yellow,yellow,',
#  'blue,blue,yellow,black,blue,white,bone,green,rainbow,green,white,red,rainbow,',
#  'blue,blue,yellow,bone,green,grey,teal,',
#  'blue,blue,yellow,chrome,',
#  'blue,bone,aqua,red,red,',
#  'blue,bone,black,aqua,bone,blue,black,',
#  'blue,bone,black,blue,rainbow,grey,yellow,',
#  'blue,bone,orange,black,red,chrome,teal,aqua,aqua,bone,',
#  'blue,bone,red,yellow,chrome,red,blue,yellow,',
#  'blue,bone,silver,chrome,red,black,white,black,blue,',
#  'blue,bone,white,black,grey,red,yellow,',
#  'blue,bone,white,rainbow,aqua,teal,chrome,yellow,white,orange,grey,green,orange,orange,',
#  'blue,bone,yellow,',
#  'blue,chrome,',
#  'blue,chrome,black,purple,yellow,yellow,white,green,green,',
#  'blue,chrome,black,silver,bone,black,orange,purple,white,yellow,chrome,teal,',
#  'blue,chrome,blue,blue,silver,orange,',
#  'blue,chrome,blue,purple,green,rainbow,grey,rainbow,green,grey,red,',
#  'blue,chrome,grey,black,blue,',
#  'blue,chrome,grey,chrome,orange,teal,grey,aqua,rainbow,grey,yellow,orange,',
#  'blue,chrome,silver,rainbow,',
#  'blue,chrome,teal,yellow,purple,black,teal,',
#  'blue,chrome,white,orange,aqua,aqua,blue,rainbow,orange,',
#  'blue,chrome,yellow,teal,chrome,teal,chrome,',
#  'blue,green,',
#  'blue,green,black,blue,black,blue,green,orange,yellow,black,black,aqua,',
#  'blue,green,rainbow,blue,rainbow,green,orange,rainbow,yellow,yellow,grey,',
#  'blue,green,white,purple,',
#  'blue,green,white,red,grey,teal,yellow,yellow,blue,orange,green,silver,yellow,aqua,',
#  'blue,green,white,yellow,aqua,purple,green,green,silver,teal,rainbow,blue,grey,',
#  'blue,green,yellow,',
#  'blue,grey,',
#  'blue,grey,aqua,green,teal,rainbow,black,red,purple,white,',
#  'blue,grey,black,black,',
#  'blue,grey,black,teal,teal,rainbow,yellow,',
#  'blue,grey,blue,red,chrome,silver,black,',
#  'blue,grey,orange,black,silver,green,rainbow,red,purple,bone,',
#  'blue,grey,orange,yellow,purple,yellow,black,blue,silver,bone,',
#  'blue,grey,rainbow,silver,chrome,yellow,',
#  'blue,orange,',
#  'blue,orange,bone,',
#  'blue,orange,green,grey,aqua,grey,',
#  'blue,orange,purple,black,grey,red,white,',
#  'blue,orange,rainbow,white,',
#  'blue,orange,red,rainbow,grey,orange,red,purple,orange,grey,aqua,bone,orange,teal,',
#  'blue,orange,silver,white,black,chrome,green,black,yellow,teal,teal,green,red,',
#  'blue,orange,teal,',
#  'blue,orange,white,',
#  'blue,orange,yellow,green,silver,orange,rainbow,yellow,blue,',
#  'blue,purple,',
#  'blue,purple,bone,grey,orange,orange,rainbow,silver,grey,blue,silver,',
#  'blue,purple,orange,silver,yellow,purple,orange,teal,orange,silver,',
#  'blue,purple,purple,purple,rainbow,green,blue,',
#  'blue,purple,silver,green,purple,chrome,grey,white,purple,aqua,silver,rainbow,',
#  'blue,purple,yellow,yellow,white,orange,grey,orange,silver,bone,rainbow,grey,blue,black,',
#  'blue,rainbow,blue,',
#  'blue,rainbow,grey,teal,silver,yellow,',
#  'blue,rainbow,orange,aqua,',
#  'blue,rainbow,orange,bone,silver,aqua,red,',
#  'blue,rainbow,orange,silver,bone,aqua,rainbow,orange,red,silver,rainbow,blue,orange,',
#  'blue,rainbow,yellow,grey,silver,red,white,green,blue,rainbow,black,white,',
#  'blue,rainbow,yellow,orange,aqua,red,grey,aqua,orange,red,aqua,orange,blue,purple,',
#  'blue,red,',
#  'blue,red,black,red,white,yellow,rainbow,rainbow,silver,red,orange,',
#  'blue,red,blue,aqua,rainbow,teal,black,',
#  'blue,red,grey,',
#  'blue,red,red,orange,aqua,blue,orange,white,rainbow,orange,yellow,silver,white,purple,',
#  'blue,red,white,orange,black,',
#  'blue,red,white,orange,teal,red,yellow,black,white,red,yellow,',
#  'blue,silver,',
#  'blue,silver,black,chrome,grey,',
#  'blue,silver,blue,white,rainbow,aqua,yellow,silver,blue,chrome,',
#  'blue,silver,purple,orange,white,rainbow,yellow,',
#  'blue,silver,rainbow,blue,purple,purple,aqua,rainbow,chrome,bone,teal,chrome,black,',
#  'blue,silver,rainbow,orange,',
#  'blue,silver,red,bone,orange,chrome,aqua,rainbow,grey,grey,aqua,rainbow,',
#  'blue,silver,teal,purple,white,chrome,chrome,black,orange,yellow,blue,white,aqua,teal,',
#  'blue,teal,',
#  'blue,teal,black,purple,white,grey,blue,',
#  'blue,teal,blue,blue,aqua,rainbow,teal,',
#  'blue,teal,blue,rainbow,aqua,',
#  'blue,teal,bone,blue,orange,yellow,teal,orange,rainbow,',
#  'blue,teal,chrome,black,aqua,red,',
#  'blue,teal,grey,white,green,bone,silver,teal,bone,purple,teal,white,',
#  'blue,teal,purple,aqua,purple,purple,red,aqua,grey,',
#  'blue,teal,rainbow,white,rainbow,purple,silver,rainbow,grey,purple,',
#  'blue,teal,white,black,red,',
#  'blue,teal,white,orange,bone,black,chrome,white,bone,yellow,black,',
#  'blue,white,',
#  'blue,white,aqua,rainbow,yellow,bone,silver,orange,white,white,grey,purple,',
#  'blue,white,blue,aqua,red,purple,silver,black,white,chrome,aqua,teal,',
#  'blue,white,blue,grey,rainbow,aqua,red,',
#  'blue,white,chrome,rainbow,aqua,grey,purple,',
#  'blue,white,chrome,yellow,grey,blue,orange,white,',
#  'blue,white,purple,grey,red,chrome,white,purple,rainbow,aqua,green,yellow,teal,silver,',
#  'blue,white,rainbow,blue,aqua,blue,',
#  'blue,white,rainbow,chrome,orange,bone,red,teal,bone,chrome,black,red,white,green,',
#  'blue,white,rainbow,white,teal,',
#  'blue,white,red,teal,yellow,black,teal,white,',
#  'blue,white,silver,aqua,red,aqua,bone,purple,blue,grey,green,',
#  'blue,white,teal,teal,blue,',
#  'blue,yellow,',
#  'blue,yellow,blue,rainbow,green,aqua,green,yellow,chrome,purple,silver,yellow,orange,',
#  'blue,yellow,bone,blue,silver,teal,grey,green,',
#  'blue,yellow,green,aqua,aqua,grey,',
#  'blue,yellow,rainbow,',
#  'blue,yellow,silver,black,teal,',
#  'blue,yellow,teal,green,silver,black,blue,yellow,',
#  'blue,yellow,white,',
#  'bone,',
#  'bone,aqua,black,aqua,',
#  'bone,aqua,black,yellow,blue,grey,bone,',
#  'bone,aqua,purple,green,green,green,silver,',
#  'bone,aqua,red,teal,black,bone,',
#  'bone,aqua,silver,silver,purple,chrome,chrome,green,red,white,yellow,',
#  'bone,aqua,silver,teal,blue,aqua,bone,grey,green,bone,teal,',
#  'bone,aqua,teal,silver,yellow,rainbow,green,blue,silver,red,black,bone,white,',
#  'bone,aqua,white,green,',
#  'bone,aqua,yellow,teal,bone,',
#  'bone,black,',
#  'bone,black,blue,chrome,purple,grey,aqua,yellow,purple,teal,silver,chrome,',
#  'bone,black,blue,grey,teal,rainbow,red,green,teal,teal,',
#  'bone,black,bone,black,rainbow,',
#  'bone,black,bone,purple,bone,rainbow,teal,red,',
#  'bone,black,chrome,black,rainbow,chrome,green,black,purple,bone,',
#  'bone,black,grey,green,',
#  'bone,black,red,silver,chrome,aqua,grey,bone,black,',
#  'bone,black,yellow,grey,black,',
#  'bone,black,yellow,rainbow,rainbow,purple,red,aqua,aqua,green,white,chrome,silver,',
#  'bone,blue,',
#  'bone,blue,aqua,red,rainbow,green,bone,teal,purple,grey,yellow,green,',
#  'bone,blue,blue,black,rainbow,chrome,orange,silver,purple,yellow,rainbow,teal,blue,rainbow,',
#  'bone,blue,green,orange,chrome,purple,red,purple,purple,black,red,white,',
#  'bone,bone,',
#  'bone,bone,aqua,silver,yellow,yellow,teal,red,',
#  'bone,bone,blue,purple,chrome,white,teal,',
#  'bone,bone,purple,',
#  'bone,bone,purple,orange,rainbow,',
#  'bone,bone,white,rainbow,chrome,',
#  'bone,bone,white,red,white,purple,',
#  'bone,chrome,',
#  'bone,chrome,aqua,black,bone,green,',
#  'bone,chrome,blue,',
#  'bone,chrome,grey,orange,aqua,black,rainbow,green,black,silver,bone,',
#  'bone,chrome,grey,yellow,orange,',
#  'bone,chrome,orange,aqua,silver,',
#  'bone,chrome,rainbow,black,white,blue,blue,',
#  'bone,chrome,red,red,black,white,',
#  'bone,chrome,red,white,black,black,yellow,chrome,black,white,blue,silver,purple,',
#  'bone,chrome,teal,orange,teal,aqua,green,aqua,teal,black,aqua,red,',
#  'bone,chrome,white,',
#  'bone,green,',
#  'bone,green,aqua,chrome,bone,yellow,bone,',
#  'bone,green,bone,aqua,purple,chrome,teal,yellow,',
#  'bone,green,green,red,green,',
#  'bone,green,purple,black,yellow,rainbow,yellow,purple,bone,red,chrome,orange,black,',
#  'bone,green,silver,orange,chrome,silver,orange,red,orange,purple,purple,purple,purple,',
#  'bone,green,teal,orange,orange,blue,purple,rainbow,red,',
#  'bone,grey,black,yellow,aqua,grey,',
#  'bone,grey,blue,orange,blue,orange,silver,orange,',
#  'bone,grey,chrome,white,red,silver,black,green,',
#  'bone,grey,green,yellow,chrome,purple,',
#  'bone,grey,orange,purple,blue,yellow,chrome,chrome,red,',
#  'bone,grey,purple,aqua,',
#  'bone,grey,red,chrome,bone,aqua,',
#  'bone,grey,white,chrome,red,red,aqua,green,silver,grey,bone,teal,grey,blue,',
#  'bone,grey,white,teal,white,green,black,aqua,teal,bone,grey,red,purple,',
#  'bone,orange,chrome,silver,aqua,aqua,white,green,green,teal,teal,green,',
#  'bone,orange,green,',
#  'bone,orange,rainbow,yellow,teal,orange,orange,bone,green,red,',
#  'bone,orange,red,aqua,silver,grey,chrome,bone,green,green,bone,',
#  'bone,orange,red,blue,',
#  'bone,orange,silver,red,blue,',
#  'bone,orange,white,rainbow,blue,silver,blue,chrome,grey,grey,',
#  'bone,orange,yellow,chrome,purple,green,purple,teal,',
#  'bone,orange,yellow,white,',
#  'bone,purple,blue,grey,chrome,silver,white,black,grey,white,blue,red,',
#  'bone,purple,chrome,teal,yellow,silver,grey,white,black,black,orange,teal,',
#  'bone,purple,orange,yellow,bone,silver,blue,orange,green,',
#  'bone,purple,purple,aqua,teal,aqua,green,',
#  'bone,purple,purple,red,teal,teal,rainbow,grey,yellow,silver,white,',
#  'bone,purple,rainbow,',
#  'bone,purple,rainbow,blue,red,grey,purple,red,',
#  'bone,rainbow,',
#  'bone,rainbow,black,chrome,yellow,bone,orange,grey,bone,aqua,red,',
#  'bone,rainbow,green,black,silver,silver,red,purple,white,',
#  'bone,rainbow,orange,purple,aqua,purple,teal,aqua,',
#  'bone,rainbow,red,rainbow,rainbow,teal,teal,',
#  'bone,rainbow,white,silver,purple,',
#  'bone,rainbow,yellow,rainbow,red,blue,bone,green,white,black,green,yellow,red,',
#  'bone,red,',
#  'bone,red,aqua,white,bone,',
#  'bone,red,black,blue,silver,teal,chrome,silver,teal,',
#  'bone,red,black,red,',
#  'bone,red,bone,chrome,silver,white,white,silver,blue,grey,yellow,black,green,chrome,',
#  'bone,red,bone,silver,rainbow,',
#  'bone,red,chrome,green,teal,white,red,aqua,grey,aqua,green,teal,',
#  'bone,red,green,black,rainbow,',
#  'bone,red,grey,grey,chrome,silver,yellow,white,white,aqua,black,black,teal,',
#  'bone,red,orange,black,grey,yellow,purple,black,yellow,orange,bone,grey,silver,',
#  'bone,red,rainbow,black,teal,white,chrome,rainbow,',
#  'bone,red,teal,grey,yellow,grey,white,chrome,red,white,red,yellow,blue,purple,',
#  'bone,red,teal,teal,purple,red,chrome,grey,blue,aqua,silver,chrome,blue,grey,',
#  'bone,red,yellow,black,black,',
#  'bone,red,yellow,blue,',
#  'bone,silver,aqua,blue,',
#  'bone,silver,aqua,teal,black,chrome,red,purple,bone,grey,red,',
#  'bone,silver,black,silver,blue,',
#  'bone,silver,orange,red,teal,white,purple,blue,red,red,chrome,aqua,aqua,rainbow,',
#  'bone,silver,red,',
#  'bone,silver,white,',
#  'bone,silver,white,grey,yellow,rainbow,teal,bone,aqua,green,',
#  'bone,teal,black,purple,chrome,white,rainbow,blue,orange,blue,blue,yellow,',
#  'bone,teal,bone,purple,purple,black,orange,red,grey,rainbow,purple,orange,aqua,',
#  'bone,teal,purple,',
#  'bone,teal,purple,red,',
#  'bone,teal,yellow,rainbow,black,teal,',
#  'bone,white,',
#  'bone,white,aqua,white,teal,yellow,purple,bone,purple,purple,teal,purple,',
#  'bone,white,black,yellow,',
#  'bone,white,bone,black,grey,bone,white,',
#  'bone,white,chrome,orange,white,black,',
#  'bone,white,chrome,purple,orange,orange,white,green,yellow,green,grey,blue,rainbow,grey,',
#  'bone,white,purple,yellow,green,black,purple,red,silver,black,blue,',
#  'bone,white,red,red,chrome,chrome,green,',
#  'bone,yellow,bone,',
#  'bone,yellow,green,blue,silver,orange,red,',
#  'bone,yellow,red,',
#  'bone,yellow,silver,grey,black,aqua,',
#  'bone,yellow,silver,rainbow,teal,chrome,black,',
#  'bone,yellow,silver,teal,purple,chrome,aqua,grey,purple,blue,aqua,green,',
#  'bone,yellow,teal,teal,green,',
#  'bone,yellow,white,red,purple,aqua,blue,black,green,',
#  'bone,yellow,white,yellow,black,bone,silver,black,white,teal,bone,',
#  'bone,yellow,yellow,',
#  'bone,yellow,yellow,blue,red,orange,red,blue,rainbow,teal,white,bone,',
#  'bone,yellow,yellow,bone,red,teal,bone,bone,green,black,',
#  'chrome,',
#  'chrome,aqua,aqua,orange,green,grey,aqua,',
#  'chrome,aqua,blue,grey,teal,aqua,green,yellow,rainbow,purple,chrome,teal,',
#  'chrome,aqua,bone,orange,orange,rainbow,silver,black,',
#  'chrome,aqua,purple,purple,rainbow,',
#  'chrome,aqua,purple,rainbow,chrome,bone,silver,aqua,red,grey,bone,red,orange,',
#  'chrome,aqua,rainbow,bone,grey,aqua,silver,red,black,rainbow,white,yellow,chrome,',
#  'chrome,aqua,rainbow,silver,red,black,grey,black,aqua,',
#  'chrome,aqua,teal,aqua,orange,red,silver,teal,aqua,chrome,red,grey,',
#  'chrome,aqua,teal,orange,green,chrome,red,white,purple,rainbow,bone,grey,aqua,',
#  'chrome,black,aqua,white,red,black,blue,red,blue,teal,',
#  'chrome,black,black,black,purple,purple,',
#  'chrome,black,blue,silver,black,grey,',
#  'chrome,black,bone,green,',
#  'chrome,black,chrome,silver,rainbow,chrome,purple,red,grey,grey,orange,chrome,',
#  'chrome,black,green,green,',
#  'chrome,black,silver,bone,orange,rainbow,silver,aqua,silver,purple,blue,white,bone,',
#  'chrome,black,teal,orange,rainbow,teal,red,yellow,black,green,purple,red,',
#  'chrome,black,white,orange,white,orange,bone,red,rainbow,teal,',
#  'chrome,black,white,red,yellow,aqua,',
#  'chrome,black,yellow,',
#  'chrome,blue,',
#  'chrome,blue,blue,white,black,blue,rainbow,',
#  'chrome,blue,orange,chrome,teal,grey,white,teal,aqua,white,',
#  'chrome,blue,purple,red,rainbow,aqua,yellow,',
#  'chrome,blue,rainbow,grey,aqua,white,black,silver,purple,silver,white,grey,white,',
#  'chrome,blue,red,aqua,silver,rainbow,black,red,chrome,',
#  'chrome,blue,red,black,teal,white,yellow,grey,grey,chrome,aqua,',
#  'chrome,blue,teal,orange,',
#  'chrome,blue,yellow,blue,blue,silver,',
#  'chrome,bone,',
#  'chrome,bone,red,rainbow,aqua,teal,red,grey,grey,black,bone,blue,grey,',
#  'chrome,bone,teal,white,orange,white,red,',
#  'chrome,bone,white,',
#  'chrome,bone,white,bone,orange,yellow,white,red,red,teal,',
#  'chrome,bone,white,rainbow,white,',
#  'chrome,chrome,aqua,',
#  'chrome,chrome,black,purple,aqua,',
#  'chrome,chrome,bone,',
#  'chrome,chrome,chrome,yellow,chrome,green,silver,rainbow,blue,aqua,grey,',
#  'chrome,chrome,green,white,green,black,chrome,white,chrome,white,bone,bone,',
#  'chrome,chrome,orange,chrome,yellow,grey,rainbow,yellow,yellow,grey,aqua,red,',
#  'chrome,chrome,yellow,teal,yellow,bone,silver,chrome,green,aqua,bone,teal,',
#  'chrome,green,',
#  'chrome,green,blue,blue,silver,blue,red,yellow,grey,teal,',
#  'chrome,green,bone,grey,green,black,grey,yellow,chrome,silver,silver,yellow,',
#  'chrome,green,chrome,chrome,grey,bone,aqua,orange,chrome,black,',
#  'chrome,green,chrome,silver,yellow,rainbow,blue,black,white,purple,green,grey,orange,',
#  'chrome,green,orange,orange,blue,red,black,rainbow,aqua,yellow,bone,teal,',
#  'chrome,green,rainbow,green,white,green,teal,white,',
#  'chrome,green,yellow,orange,grey,green,teal,purple,grey,rainbow,grey,blue,teal,',
#  'chrome,grey,black,teal,rainbow,yellow,blue,',
#  'chrome,grey,blue,white,grey,aqua,aqua,orange,green,',
#  'chrome,grey,silver,rainbow,blue,teal,teal,rainbow,rainbow,purple,grey,rainbow,',
#  'chrome,grey,teal,chrome,silver,',
#  'chrome,grey,white,bone,black,blue,yellow,green,red,grey,red,',
#  'chrome,orange,',
#  'chrome,orange,black,grey,',
#  'chrome,orange,bone,rainbow,aqua,red,bone,',
#  'chrome,orange,chrome,black,',
#  'chrome,orange,red,green,teal,yellow,chrome,bone,purple,grey,white,white,silver,blue,',
#  'chrome,orange,red,grey,green,yellow,blue,',
#  'chrome,orange,silver,bone,teal,aqua,purple,bone,rainbow,yellow,yellow,yellow,',
#  'chrome,orange,teal,black,orange,teal,rainbow,',
#  'chrome,orange,white,black,yellow,',
#  'chrome,purple,aqua,yellow,orange,red,silver,purple,purple,chrome,grey,bone,rainbow,',
#  'chrome,purple,black,aqua,grey,blue,red,',
#  'chrome,purple,black,black,yellow,silver,orange,silver,red,bone,aqua,black,',
#  'chrome,purple,black,purple,grey,grey,green,black,',
#  'chrome,purple,bone,aqua,yellow,aqua,teal,yellow,green,',
#  'chrome,purple,green,orange,aqua,teal,blue,chrome,',
#  'chrome,purple,grey,aqua,white,chrome,aqua,',
#  'chrome,purple,purple,rainbow,grey,rainbow,grey,white,silver,silver,green,rainbow,yellow,',
#  'chrome,purple,silver,black,green,',
#  'chrome,purple,white,chrome,green,black,grey,black,orange,orange,purple,blue,green,',
#  'chrome,purple,white,rainbow,grey,blue,green,green,teal,green,',
#  'chrome,rainbow,',
#  'chrome,rainbow,aqua,',
#  'chrome,rainbow,aqua,blue,red,bone,rainbow,chrome,purple,teal,blue,aqua,',
#  'chrome,rainbow,aqua,chrome,black,purple,grey,green,',
#  'chrome,rainbow,aqua,red,purple,green,teal,purple,white,yellow,black,orange,white,',
#  'chrome,rainbow,green,silver,grey,',
#  'chrome,rainbow,green,yellow,chrome,yellow,',
#  'chrome,rainbow,grey,red,blue,chrome,',
#  'chrome,rainbow,orange,aqua,grey,red,',
#  'chrome,rainbow,purple,silver,grey,white,green,purple,green,',
#  'chrome,rainbow,teal,orange,silver,black,silver,rainbow,white,green,aqua,red,blue,',
#  'chrome,rainbow,white,',
#  'chrome,rainbow,white,bone,',
#  'chrome,rainbow,yellow,grey,',
#  'chrome,red,black,green,rainbow,silver,',
#  'chrome,red,blue,chrome,rainbow,yellow,black,orange,blue,orange,',
#  'chrome,red,chrome,chrome,silver,teal,silver,black,grey,',
#  'chrome,red,rainbow,',
#  'chrome,red,rainbow,black,purple,blue,',
#  'chrome,red,red,orange,purple,bone,black,black,yellow,blue,black,orange,grey,yellow,',
#  'chrome,silver,black,',
#  'chrome,silver,black,teal,purple,white,orange,red,',
#  'chrome,silver,bone,black,',
#  'chrome,silver,chrome,blue,green,teal,aqua,grey,bone,aqua,purple,',
#  'chrome,silver,green,',
#  'chrome,silver,white,blue,rainbow,bone,yellow,grey,chrome,silver,grey,aqua,teal,chrome,',
#  'chrome,teal,aqua,teal,green,white,yellow,purple,',
#  'chrome,teal,blue,yellow,silver,black,aqua,bone,purple,green,blue,grey,rainbow,',
#  'chrome,teal,chrome,',
#  'chrome,teal,orange,purple,silver,silver,',
#  'chrome,teal,rainbow,green,chrome,yellow,silver,white,blue,white,silver,green,blue,',
#  'chrome,teal,rainbow,teal,silver,white,',
#  'chrome,teal,red,green,teal,bone,black,white,green,yellow,orange,chrome,',
#  'chrome,teal,silver,bone,',
#  'chrome,teal,yellow,orange,purple,teal,rainbow,aqua,grey,chrome,yellow,grey,orange,white,',
#  'chrome,teal,yellow,purple,white,',
#  'chrome,white,blue,purple,green,white,white,bone,green,rainbow,grey,',
#  'chrome,white,bone,rainbow,black,black,black,blue,red,teal,',
#  'chrome,white,bone,teal,orange,bone,aqua,grey,',
#  'chrome,white,green,blue,purple,green,purple,purple,yellow,white,rainbow,blue,chrome,green,',
#  'chrome,white,grey,bone,red,aqua,',
#  'chrome,white,grey,chrome,silver,orange,blue,aqua,rainbow,red,green,orange,aqua,purple,',
#  'chrome,white,silver,aqua,blue,black,yellow,',
#  'chrome,white,silver,blue,black,bone,silver,chrome,grey,rainbow,grey,rainbow,',
#  'chrome,white,silver,bone,silver,bone,bone,grey,silver,grey,black,green,rainbow,',
#  'chrome,white,white,chrome,teal,rainbow,bone,',
#  'chrome,yellow,',
#  'chrome,yellow,bone,black,yellow,red,aqua,bone,red,silver,bone,orange,rainbow,chrome,',
#  'chrome,yellow,bone,green,blue,',
#  'chrome,yellow,chrome,teal,',
#  'chrome,yellow,green,grey,purple,',
#  'chrome,yellow,orange,chrome,',
#  'chrome,yellow,purple,green,rainbow,',
#  'chrome,yellow,purple,red,bone,black,yellow,blue,black,',
#  'chrome,yellow,red,purple,chrome,white,silver,white,blue,purple,orange,',
#  'chrome,yellow,silver,',
#  'chrome,yellow,teal,teal,green,black,yellow,chrome,grey,yellow,purple,black,teal,red,',
#  'green,',
#  'green,aqua,black,white,orange,aqua,',
#  'green,aqua,blue,rainbow,orange,purple,orange,black,bone,bone,white,silver,chrome,red,',
#  'green,aqua,blue,teal,chrome,blue,white,red,purple,black,',
#  'green,aqua,bone,white,',
#  'green,aqua,green,blue,green,yellow,',
#  'green,aqua,orange,green,white,grey,',
#  'green,aqua,purple,',
#  'green,aqua,purple,blue,chrome,bone,green,green,',
#  'green,aqua,rainbow,yellow,chrome,chrome,red,',
#  'green,aqua,silver,rainbow,blue,silver,black,grey,white,silver,black,silver,white,',
#  'green,aqua,silver,teal,black,teal,blue,red,white,silver,bone,',
#  'green,aqua,teal,silver,purple,orange,black,bone,white,rainbow,silver,',
#  'green,aqua,white,',
#  'green,aqua,white,yellow,chrome,blue,silver,teal,red,orange,green,',
#  'green,black,',
#  'green,black,blue,',
#  'green,black,blue,black,orange,aqua,rainbow,black,aqua,yellow,chrome,purple,rainbow,yellow,',
#  'green,black,blue,bone,rainbow,white,rainbow,purple,purple,black,green,grey,red,',
#  'green,black,chrome,white,aqua,green,grey,white,',
#  'green,black,green,red,green,grey,teal,',
#  'green,black,orange,rainbow,chrome,rainbow,red,chrome,aqua,',
#  'green,black,purple,red,white,grey,blue,purple,teal,aqua,',
#  'green,black,teal,aqua,black,chrome,rainbow,',
#  'green,black,teal,grey,silver,black,chrome,orange,white,blue,yellow,orange,blue,rainbow,',
#  'green,blue,black,bone,teal,yellow,bone,black,orange,purple,green,white,silver,',
#  'green,blue,black,teal,teal,chrome,silver,chrome,white,teal,green,green,',
#  'green,blue,green,aqua,blue,chrome,teal,',
#  'green,blue,green,white,silver,blue,orange,red,black,',
#  'green,blue,red,blue,grey,chrome,',
#  'green,blue,teal,white,grey,yellow,black,silver,',
#  'green,bone,aqua,',
#  'green,bone,green,red,',
#  'green,bone,orange,teal,green,teal,white,purple,chrome,red,',
#  'green,bone,orange,teal,yellow,red,orange,purple,blue,grey,bone,rainbow,',
#  'green,bone,red,green,silver,green,yellow,yellow,white,silver,red,chrome,',
#  'green,bone,yellow,aqua,blue,purple,white,chrome,chrome,grey,bone,',
#  'green,chrome,blue,grey,rainbow,blue,orange,grey,aqua,grey,bone,',
#  'green,chrome,bone,aqua,rainbow,grey,grey,',
#  'green,chrome,grey,rainbow,teal,black,blue,blue,',
#  'green,chrome,orange,',
#  'green,chrome,purple,blue,chrome,black,',
#  'green,chrome,silver,red,purple,silver,red,teal,grey,',
#  'green,chrome,white,grey,orange,orange,aqua,silver,chrome,orange,bone,teal,bone,',
#  'green,green,',
#  'green,green,black,purple,silver,black,orange,bone,aqua,',
#  'green,green,bone,red,white,chrome,aqua,silver,silver,orange,green,',
#  'green,green,chrome,black,blue,teal,yellow,',
#  'green,green,grey,rainbow,silver,chrome,orange,rainbow,aqua,grey,silver,',
#  'green,green,orange,white,white,silver,grey,white,blue,',
#  'green,green,red,yellow,aqua,bone,',
#  'green,green,silver,black,red,teal,red,orange,',
#  'green,green,white,grey,silver,black,aqua,',
#  'green,green,white,orange,rainbow,',
#  'green,green,yellow,red,purple,rainbow,orange,chrome,orange,bone,grey,white,chrome,',
#  'green,grey,aqua,rainbow,rainbow,',
#  'green,grey,bone,teal,white,purple,silver,purple,bone,bone,',
#  'green,grey,chrome,',
#  'green,grey,grey,yellow,aqua,blue,aqua,yellow,',
#  'green,grey,rainbow,white,white,orange,yellow,bone,red,white,silver,green,yellow,',
#  'green,grey,red,chrome,blue,teal,green,black,orange,rainbow,aqua,aqua,',
#  'green,grey,teal,blue,teal,',
#  'green,orange,aqua,orange,',
#  'green,orange,black,teal,orange,bone,green,bone,bone,chrome,green,',
#  'green,orange,chrome,aqua,red,grey,',
#  'green,orange,chrome,silver,green,chrome,aqua,',
#  'green,orange,green,green,chrome,',
#  'green,orange,grey,chrome,rainbow,bone,aqua,blue,black,teal,aqua,purple,bone,',
#  'green,orange,orange,green,blue,purple,black,chrome,orange,bone,',
#  'green,purple,',
#  'green,purple,blue,chrome,purple,silver,grey,orange,teal,purple,grey,',
#  'green,purple,bone,red,yellow,teal,green,red,silver,yellow,silver,rainbow,orange,',
#  'green,purple,green,grey,chrome,green,yellow,purple,black,grey,bone,silver,red,yellow,',
#  'green,purple,orange,bone,bone,chrome,aqua,orange,silver,red,purple,',
#  'green,purple,orange,rainbow,blue,rainbow,bone,',
#  'green,purple,rainbow,yellow,yellow,orange,green,',
#  'green,rainbow,',
#  'green,rainbow,aqua,rainbow,aqua,purple,grey,chrome,aqua,teal,rainbow,yellow,orange,grey,',
#  'green,rainbow,black,black,rainbow,',
#  'green,rainbow,black,chrome,purple,teal,',
#  'green,rainbow,bone,',
#  'green,rainbow,bone,aqua,blue,grey,rainbow,grey,black,silver,orange,black,',
#  'green,rainbow,rainbow,',
#  'green,rainbow,rainbow,blue,bone,rainbow,',
#  'green,rainbow,red,white,teal,chrome,orange,silver,green,bone,teal,red,silver,',
#  'green,rainbow,silver,bone,teal,purple,blue,green,silver,red,black,rainbow,aqua,aqua,',
#  'green,rainbow,teal,',
#  'green,rainbow,teal,grey,green,teal,black,yellow,green,',
#  'green,red,aqua,chrome,black,chrome,blue,grey,yellow,purple,',
#  'green,red,black,',
#  'green,red,chrome,',
#  'green,red,chrome,purple,teal,orange,purple,yellow,red,blue,aqua,silver,',
#  'green,red,green,red,silver,teal,bone,green,chrome,',
#  'green,red,orange,green,yellow,aqua,blue,green,bone,purple,blue,chrome,',
#  'green,red,purple,orange,green,silver,red,white,orange,white,chrome,teal,blue,orange,',
#  'green,red,rainbow,orange,green,green,aqua,',
#  'green,red,red,grey,blue,silver,rainbow,black,green,orange,purple,aqua,yellow,',
#  'green,red,silver,teal,red,',
#  'green,red,teal,chrome,bone,bone,orange,',
#  'green,silver,',
#  'green,silver,aqua,',
#  'green,silver,green,aqua,silver,bone,blue,',
#  'green,silver,green,blue,aqua,green,green,silver,red,chrome,',
#  'green,silver,grey,yellow,rainbow,teal,',
#  'green,silver,purple,rainbow,purple,green,rainbow,blue,rainbow,black,',
#  'green,silver,purple,silver,green,rainbow,',
#  'green,silver,silver,purple,silver,rainbow,green,',
#  'green,silver,yellow,orange,black,chrome,orange,orange,blue,rainbow,silver,rainbow,silver,yellow,',
#  'green,teal,aqua,chrome,',
#  'green,teal,black,silver,silver,grey,grey,black,silver,rainbow,red,',
#  'green,teal,purple,purple,green,orange,red,aqua,yellow,aqua,blue,white,bone,teal,',
#  'green,teal,red,red,blue,',
#  'green,teal,yellow,orange,green,',
#  'green,teal,yellow,yellow,blue,bone,bone,aqua,red,orange,red,rainbow,black,',
#  'green,white,black,bone,yellow,orange,purple,yellow,bone,black,',
#  'green,white,chrome,bone,blue,',
#  'green,white,green,black,blue,grey,aqua,chrome,teal,silver,orange,green,silver,orange,',
#  'green,white,green,rainbow,orange,grey,red,yellow,white,aqua,purple,aqua,aqua,',
#  'green,white,silver,aqua,grey,green,chrome,',
#  'green,white,teal,aqua,rainbow,teal,',
#  'green,yellow,',
#  'green,yellow,aqua,',
#  'green,yellow,orange,black,red,chrome,red,orange,blue,yellow,yellow,',
#  'green,yellow,rainbow,rainbow,teal,blue,',
#  'green,yellow,white,',
#  'grey,',
#  'grey,aqua,black,green,yellow,red,',
#  'grey,aqua,blue,black,silver,black,yellow,teal,blue,blue,',
#  'grey,aqua,orange,purple,blue,white,',
#  'grey,aqua,purple,black,silver,silver,aqua,teal,',
#  'grey,aqua,purple,chrome,silver,rainbow,yellow,green,grey,',
#  'grey,aqua,rainbow,black,rainbow,rainbow,purple,orange,aqua,orange,white,orange,grey,teal,',
#  'grey,aqua,rainbow,blue,black,chrome,white,',
#  'grey,aqua,rainbow,teal,silver,green,blue,grey,green,purple,green,aqua,chrome,',
#  'grey,aqua,silver,white,',
#  'grey,aqua,teal,yellow,teal,orange,red,yellow,silver,white,yellow,rainbow,rainbow,black,',
#  'grey,black,black,yellow,white,purple,red,',
#  'grey,black,bone,silver,green,purple,bone,black,',
#  'grey,black,bone,white,blue,red,red,orange,aqua,green,teal,',
#  'grey,black,green,aqua,',
#  'grey,black,green,grey,rainbow,',
#  'grey,black,orange,yellow,blue,',
#  'grey,black,purple,aqua,purple,black,teal,white,purple,silver,yellow,',
#  'grey,black,purple,aqua,teal,silver,blue,black,orange,green,green,',
#  'grey,black,purple,purple,teal,blue,bone,white,orange,orange,',
#  'grey,black,rainbow,chrome,rainbow,chrome,',
#  'grey,black,silver,purple,aqua,white,',
#  'grey,black,teal,black,blue,purple,yellow,',
#  'grey,black,teal,yellow,red,green,orange,yellow,purple,teal,teal,white,chrome,',
#  'grey,black,white,bone,orange,red,grey,aqua,chrome,blue,grey,yellow,blue,',
#  'grey,black,white,orange,black,purple,grey,white,',
#  'grey,black,yellow,silver,teal,yellow,green,teal,grey,blue,teal,yellow,',
#  'grey,blue,aqua,grey,silver,rainbow,teal,white,chrome,blue,aqua,grey,grey,',
#  'grey,blue,aqua,rainbow,aqua,bone,white,red,yellow,rainbow,',
#  'grey,blue,black,teal,black,purple,yellow,teal,black,black,white,orange,',
#  'grey,blue,green,purple,black,purple,',
#  'grey,blue,rainbow,bone,rainbow,rainbow,chrome,',
#  'grey,blue,rainbow,chrome,',
#  'grey,blue,silver,aqua,',
#  'grey,blue,silver,blue,white,black,yellow,black,',
#  'grey,blue,silver,grey,rainbow,teal,chrome,teal,red,green,blue,silver,white,aqua,',
#  'grey,blue,silver,grey,yellow,silver,blue,purple,grey,chrome,blue,black,yellow,red,',
#  'grey,blue,white,purple,green,aqua,black,teal,red,chrome,bone,grey,',
#  'grey,blue,yellow,white,yellow,teal,bone,yellow,',
#  'grey,bone,',
#  'grey,bone,aqua,',
#  'grey,bone,black,blue,',
#  'grey,bone,bone,silver,yellow,',
#  'grey,bone,chrome,',
#  'grey,bone,green,orange,yellow,bone,black,rainbow,',
#  'grey,bone,green,rainbow,',
#  'grey,bone,rainbow,',
#  'grey,bone,silver,grey,chrome,aqua,blue,',
#  'grey,chrome,aqua,black,orange,purple,rainbow,chrome,',
#  'grey,chrome,aqua,rainbow,black,orange,white,chrome,blue,purple,bone,yellow,',
#  'grey,chrome,blue,rainbow,rainbow,purple,grey,rainbow,blue,white,rainbow,rainbow,yellow,teal,',
#  'grey,chrome,green,aqua,',
#  'grey,chrome,grey,',
#  'grey,chrome,orange,purple,rainbow,chrome,chrome,black,grey,',
#  'grey,chrome,purple,aqua,orange,red,chrome,teal,aqua,silver,white,grey,',
#  'grey,chrome,rainbow,teal,black,',
#  'grey,chrome,teal,',
#  'grey,chrome,teal,aqua,orange,white,',
#  'grey,chrome,white,',
#  'grey,chrome,white,orange,purple,',
#  'grey,chrome,yellow,red,',
#  'grey,green,',
#  'grey,green,blue,rainbow,red,rainbow,purple,',
#  'grey,green,blue,yellow,rainbow,purple,teal,rainbow,chrome,black,orange,',
#  'grey,green,bone,aqua,aqua,',
#  'grey,green,bone,grey,chrome,green,blue,red,chrome,purple,teal,',
#  'grey,green,purple,chrome,chrome,teal,blue,bone,purple,bone,chrome,black,aqua,',
#  'grey,green,purple,white,black,teal,purple,green,blue,',
#  'grey,green,rainbow,aqua,purple,white,green,chrome,blue,',
#  'grey,green,rainbow,black,green,yellow,bone,teal,',
#  'grey,green,red,black,purple,white,rainbow,purple,rainbow,purple,black,',
#  'grey,green,teal,',
#  'grey,grey,',
#  'grey,grey,aqua,aqua,red,',
#  'grey,grey,black,black,black,white,',
#  'grey,grey,black,black,yellow,',
#  'grey,grey,black,grey,orange,green,',
#  'grey,grey,black,grey,white,green,chrome,rainbow,purple,aqua,black,white,',
#  'grey,grey,blue,aqua,yellow,bone,aqua,teal,yellow,teal,bone,aqua,',
#  'grey,grey,bone,purple,white,red,',
#  'grey,grey,chrome,black,bone,red,',
#  'grey,grey,green,yellow,bone,yellow,orange,bone,black,',
#  'grey,grey,silver,orange,orange,black,',
#  'grey,grey,teal,red,chrome,yellow,bone,red,grey,yellow,green,red,aqua,yellow,',
#  'grey,grey,yellow,chrome,bone,blue,rainbow,blue,silver,',
#  'grey,orange,',
#  'grey,orange,bone,white,purple,orange,black,bone,chrome,bone,teal,',
#  'grey,orange,chrome,blue,bone,teal,yellow,red,red,aqua,yellow,',
#  'grey,orange,green,teal,blue,',
#  'grey,orange,orange,rainbow,silver,aqua,orange,aqua,rainbow,chrome,black,rainbow,bone,rainbow,',
#  'grey,orange,purple,rainbow,grey,bone,grey,',
#  'grey,orange,red,purple,black,',
#  'grey,orange,teal,',
#  'grey,orange,teal,silver,black,orange,',
#  'grey,orange,teal,teal,white,',
#  'grey,orange,white,black,',
#  'grey,orange,yellow,',
#  'grey,orange,yellow,aqua,silver,',
#  'grey,purple,black,black,bone,purple,black,teal,',
#  'grey,purple,black,blue,purple,orange,yellow,',
#  'grey,purple,blue,purple,orange,green,chrome,orange,aqua,',
#  'grey,purple,blue,silver,chrome,white,red,',
#  'grey,purple,blue,white,black,',
#  'grey,purple,chrome,yellow,yellow,chrome,',
#  'grey,purple,green,bone,',
#  'grey,purple,grey,blue,black,teal,',
#  'grey,purple,orange,orange,aqua,teal,blue,yellow,chrome,blue,teal,yellow,yellow,',
#  'grey,purple,purple,black,grey,white,orange,rainbow,silver,orange,chrome,chrome,',
#  'grey,purple,rainbow,chrome,white,rainbow,green,bone,teal,blue,green,bone,bone,',
#  'grey,purple,white,grey,teal,silver,rainbow,blue,',
#  'grey,purple,white,red,red,green,rainbow,purple,silver,yellow,purple,silver,',
#  'grey,rainbow,',
#  'grey,rainbow,bone,chrome,',
#  'grey,rainbow,teal,blue,silver,green,red,',
#  'grey,rainbow,teal,silver,teal,black,yellow,green,grey,green,yellow,red,silver,bone,',
#  'grey,rainbow,white,yellow,chrome,white,green,chrome,rainbow,',
#  'grey,red,',
#  'grey,red,aqua,red,orange,teal,black,purple,blue,chrome,yellow,',
#  'grey,red,aqua,silver,aqua,black,orange,aqua,purple,green,',
#  'grey,red,bone,chrome,chrome,black,yellow,red,aqua,aqua,black,orange,rainbow,',
#  'grey,red,bone,purple,grey,orange,',
#  'grey,red,orange,red,silver,grey,chrome,rainbow,purple,green,',
#  'grey,red,rainbow,chrome,purple,rainbow,',
#  'grey,red,silver,bone,blue,silver,grey,orange,aqua,white,aqua,grey,white,bone,',
#  'grey,red,silver,green,bone,rainbow,grey,rainbow,bone,green,white,purple,teal,bone,',
#  'grey,red,yellow,bone,green,',
#  'grey,silver,bone,aqua,bone,yellow,rainbow,aqua,',
#  'grey,silver,bone,red,rainbow,yellow,',
#  'grey,silver,green,green,aqua,teal,silver,silver,teal,',
#  'grey,silver,purple,orange,',
#  'grey,silver,rainbow,silver,teal,green,',
#  'grey,silver,red,purple,silver,green,',
#  'grey,silver,silver,chrome,silver,chrome,black,',
#  'grey,silver,yellow,yellow,purple,aqua,rainbow,grey,purple,',
#  'grey,teal,',
#  'grey,teal,aqua,purple,chrome,bone,bone,yellow,red,chrome,orange,black,aqua,blue,',
#  'grey,teal,black,blue,teal,bone,grey,purple,rainbow,bone,',
#  'grey,teal,blue,orange,black,aqua,white,',
#  'grey,teal,blue,red,black,purple,rainbow,rainbow,blue,purple,orange,orange,red,',
#  'grey,teal,blue,red,purple,bone,chrome,aqua,purple,teal,orange,',
#  'grey,teal,bone,bone,teal,blue,silver,black,white,purple,grey,aqua,teal,silver,',
#  'grey,teal,chrome,white,bone,purple,chrome,orange,black,blue,green,',
#  'grey,teal,chrome,white,orange,red,',
#  'grey,teal,grey,aqua,red,black,bone,teal,green,green,red,',
#  'grey,teal,grey,bone,orange,red,orange,red,black,red,chrome,rainbow,white,white,',
#  'grey,teal,red,bone,silver,yellow,aqua,blue,rainbow,red,rainbow,teal,black,purple,',
#  'grey,teal,red,purple,purple,chrome,orange,rainbow,chrome,teal,',
#  'grey,teal,teal,',
#  'grey,teal,white,bone,silver,orange,',
#  'grey,teal,yellow,',
#  'grey,teal,yellow,white,black,silver,teal,bone,chrome,green,grey,grey,yellow,',
#  'grey,white,chrome,blue,',
#  'grey,white,chrome,green,rainbow,',
#  'grey,white,green,grey,chrome,green,black,chrome,blue,teal,chrome,',
#  'grey,white,grey,bone,red,purple,yellow,yellow,yellow,',
#  'grey,white,purple,purple,',
#  'grey,white,red,grey,blue,orange,',
#  'grey,white,red,red,yellow,aqua,silver,aqua,yellow,bone,green,rainbow,blue,silver,',
#  'grey,white,teal,aqua,orange,',
#  'grey,white,yellow,',
#  'grey,yellow,black,blue,white,orange,aqua,teal,chrome,silver,grey,',
#  'grey,yellow,black,teal,rainbow,chrome,black,blue,red,aqua,',
#  'grey,yellow,blue,bone,teal,aqua,aqua,chrome,blue,purple,grey,',
#  'grey,yellow,bone,black,',
#  'grey,yellow,green,chrome,white,yellow,grey,rainbow,bone,orange,chrome,blue,yellow,',
#  'grey,yellow,green,grey,red,aqua,silver,green,black,grey,grey,blue,',
#  'grey,yellow,purple,green,silver,rainbow,orange,green,bone,',
#  'grey,yellow,red,red,white,chrome,grey,teal,',
#  'grey,yellow,red,silver,green,bone,bone,yellow,green,',
#  'grey,yellow,white,green,yellow,bone,rainbow,teal,orange,purple,rainbow,',
#  'orange,',
#  'orange,aqua,blue,white,purple,',
#  'orange,aqua,chrome,rainbow,chrome,',
#  'orange,aqua,grey,orange,black,rainbow,grey,black,orange,rainbow,rainbow,grey,',
#  'orange,aqua,grey,red,silver,white,purple,aqua,green,yellow,purple,blue,silver,grey,',
#  'orange,aqua,orange,green,bone,blue,purple,purple,black,',
#  'orange,aqua,purple,bone,blue,grey,rainbow,bone,silver,bone,purple,bone,',
#  'orange,aqua,silver,aqua,aqua,yellow,aqua,chrome,aqua,grey,grey,',
#  'orange,black,bone,bone,rainbow,red,blue,chrome,',
#  'orange,black,bone,silver,bone,bone,red,teal,red,chrome,bone,orange,',
#  'orange,black,purple,',
#  'orange,black,purple,silver,blue,bone,grey,teal,white,',
#  'orange,black,rainbow,black,',
#  'orange,black,rainbow,bone,red,teal,chrome,white,aqua,orange,red,yellow,',
#  'orange,black,red,',
#  'orange,black,white,orange,yellow,red,yellow,green,silver,rainbow,white,aqua,',
#  'orange,blue,black,grey,white,purple,chrome,chrome,rainbow,yellow,orange,',
#  'orange,blue,bone,green,bone,red,black,silver,orange,aqua,',
#  'orange,blue,bone,red,orange,red,aqua,teal,purple,aqua,green,orange,',
#  'orange,blue,green,',
#  'orange,blue,rainbow,black,chrome,red,',
#  'orange,blue,rainbow,red,',
#  'orange,blue,teal,black,grey,bone,red,purple,',
#  'orange,blue,white,bone,grey,grey,aqua,chrome,purple,rainbow,',
#  'orange,blue,white,orange,red,black,blue,bone,aqua,',
#  'orange,bone,',
#  'orange,bone,aqua,green,teal,chrome,',
#  'orange,bone,green,grey,yellow,grey,green,aqua,aqua,rainbow,white,red,',
#  'orange,bone,grey,red,yellow,black,purple,',
#  'orange,bone,orange,grey,green,black,black,bone,chrome,white,white,silver,rainbow,white,',
#  'orange,bone,orange,white,purple,rainbow,white,chrome,',
#  'orange,bone,purple,aqua,white,red,aqua,aqua,rainbow,chrome,',
#  'orange,chrome,',
#  'orange,chrome,blue,grey,rainbow,blue,green,rainbow,',
#  'orange,chrome,blue,purple,chrome,rainbow,grey,aqua,white,',
#  'orange,chrome,bone,orange,teal,grey,white,teal,black,black,orange,silver,blue,',
#  'orange,chrome,chrome,green,orange,grey,black,',
#  'orange,chrome,chrome,purple,silver,yellow,green,',
#  'orange,chrome,teal,white,',
#  'orange,chrome,yellow,blue,silver,teal,yellow,grey,bone,green,aqua,aqua,red,chrome,',
#  'orange,green,',
#  'orange,green,bone,yellow,aqua,black,aqua,aqua,silver,green,',
#  'orange,green,green,purple,blue,black,chrome,blue,bone,purple,blue,',
#  'orange,green,green,purple,bone,silver,rainbow,yellow,yellow,purple,blue,blue,chrome,',
#  ...]

# %%
uniq_terms = []
delimeter = ','

for item in uniq_cats:
    
    split = item.split(delimeter)
    for term in split:
        if len(term) > 0 and term not in uniq_terms:
            uniq_terms.append(term)

# %%
uniq_terms = sorted(uniq_terms)
uniq_terms
# Out:
# ['aqua',
#  'black',
#  'blue',
#  'bone',
#  'chrome',
#  'green',
#  'grey',
#  'orange',
#  'purple',
#  'rainbow',
#  'red',
#  'silver',
#  'teal',
#  'white',
#  'yellow']

# %% [markdown]
# ### Combinations from `itertools`

# %%
combos = list(combinations(uniq_terms, 2))
doub_list = sorted([(y, x) for x, y in combos] + combos)

# %%
for x,y in enumerate(combos):
    first = y[0]
    second = y[1] 
    subset = data[data['cats'].str.contains(first) & data['cats'].str.contains(second)]
    print(x,y,subset.shape)
# Out:
# 0 ('aqua', 'black') (332, 2)
# 1 ('aqua', 'blue') (342, 2)
# 2 ('aqua', 'bone') (350, 2)
# 3 ('aqua', 'chrome') (362, 2)
# 4 ('aqua', 'green') (360, 2)
# 5 ('aqua', 'grey') (374, 2)
# 6 ('aqua', 'orange') (354, 2)
# 7 ('aqua', 'purple') (336, 2)
# 8 ('aqua', 'rainbow') (355, 2)
# 9 ('aqua', 'red') (360, 2)
# 10 ('aqua', 'silver') (365, 2)
# 11 ('aqua', 'teal') (352, 2)
# 12 ('aqua', 'white') (361, 2)
# 13 ('aqua', 'yellow') (356, 2)
# 14 ('black', 'blue') (357, 2)
# 15 ('black', 'bone') (362, 2)
# 16 ('black', 'chrome') (366, 2)
# 17 ('black', 'green') (343, 2)
# 18 ('black', 'grey') (363, 2)
# 19 ('black', 'orange') (353, 2)
# 20 ('black', 'purple') (354, 2)
# 21 ('black', 'rainbow') (335, 2)
# 22 ('black', 'red') (369, 2)
# 23 ('black', 'silver') (360, 2)
# 24 ('black', 'teal') (366, 2)
# 25 ('black', 'white') (367, 2)
# 26 ('black', 'yellow') (363, 2)
# 27 ('blue', 'bone') (334, 2)
# 28 ('blue', 'chrome') (372, 2)
# 29 ('blue', 'green') (358, 2)
# 30 ('blue', 'grey') (385, 2)
# 31 ('blue', 'orange') (358, 2)
# 32 ('blue', 'purple') (337, 2)
# 33 ('blue', 'rainbow') (380, 2)
# 34 ('blue', 'red') (352, 2)
# 35 ('blue', 'silver') (356, 2)
# 36 ('blue', 'teal') (377, 2)
# 37 ('blue', 'white') (379, 2)
# 38 ('blue', 'yellow') (367, 2)
# 39 ('bone', 'chrome') (353, 2)
# 40 ('bone', 'green') (350, 2)
# 41 ('bone', 'grey') (340, 2)
# 42 ('bone', 'orange') (361, 2)
# 43 ('bone', 'purple') (344, 2)
# 44 ('bone', 'rainbow') (350, 2)
# 45 ('bone', 'red') (379, 2)
# 46 ('bone', 'silver') (357, 2)
# 47 ('bone', 'teal') (347, 2)
# 48 ('bone', 'white') (358, 2)
# 49 ('bone', 'yellow') (343, 2)
# 50 ('chrome', 'green') (366, 2)
# 51 ('chrome', 'grey') (380, 2)
# 52 ('chrome', 'orange') (372, 2)
# 53 ('chrome', 'purple') (354, 2)
# 54 ('chrome', 'rainbow') (372, 2)
# 55 ('chrome', 'red') (348, 2)
# 56 ('chrome', 'silver') (364, 2)
# 57 ('chrome', 'teal') (380, 2)
# 58 ('chrome', 'white') (375, 2)
# 59 ('chrome', 'yellow') (350, 2)
# 60 ('green', 'grey') (356, 2)
# 61 ('green', 'orange') (338, 2)
# 62 ('green', 'purple') (345, 2)
# 63 ('green', 'rainbow') (364, 2)
# 64 ('green', 'red') (341, 2)
# 65 ('green', 'silver') (354, 2)
# 66 ('green', 'teal') (372, 2)
# 67 ('green', 'white') (356, 2)
# 68 ('green', 'yellow') (354, 2)
# 69 ('grey', 'orange') (352, 2)
# 70 ('grey', 'purple') (382, 2)
# 71 ('grey', 'rainbow') (368, 2)
# 72 ('grey', 'red') (339, 2)
# 73 ('grey', 'silver') (363, 2)
# 74 ('grey', 'teal') (377, 2)
# 75 ('grey', 'white') (381, 2)
# 76 ('grey', 'yellow') (375, 2)
# 77 ('orange', 'purple') (352, 2)
# 78 ('orange', 'rainbow') (358, 2)
# 79 ('orange', 'red') (365, 2)
# 80 ('orange', 'silver') (359, 2)
# 81 ('orange', 'teal') (361, 2)
# 82 ('orange', 'white') (371, 2)
# 83 ('orange', 'yellow') (362, 2)
# 84 ('purple', 'rainbow') (328, 2)
# 85 ('purple', 'red') (327, 2)
# 86 ('purple', 'silver') (338, 2)
# 87 ('purple', 'teal') (359, 2)
# 88 ('purple', 'white') (377, 2)
# 89 ('purple', 'yellow') (337, 2)
# 90 ('rainbow', 'red') (360, 2)
# 91 ('rainbow', 'silver') (370, 2)
# 92 ('rainbow', 'teal') (379, 2)
# 93 ('rainbow', 'white') (373, 2)
# 94 ('rainbow', 'yellow') (362, 2)
# 95 ('red', 'silver') (369, 2)
# 96 ('red', 'teal') (355, 2)
# 97 ('red', 'white') (370, 2)
# 98 ('red', 'yellow') (372, 2)
# 99 ('silver', 'teal') (352, 2)
# 100 ('silver', 'white') (367, 2)
# 101 ('silver', 'yellow') (366, 2)
# 102 ('teal', 'white') (375, 2)
# 103 ('teal', 'yellow') (366, 2)
# 104 ('white', 'yellow') (352, 2)
